# %%
# %cd ../yolov5/
# %pwd
# Out:
# /Users/zma/Documents/GitHub/isa_vehicle_detection/yolov5
# '/Users/zma/Documents/GitHub/isa_vehicle_detection/yolov5'

# %%
# !pip install -r requirements.txt
# Out:
# zsh:1: /Users/zma/Library/Python/3.9/bin/pip: bad interpreter: /Applications/Xcode.app/Contents/Developer/usr/bin/python3: no such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 4.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.8/882.8 kB 5.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.9 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# ...

# %%
cd ../src
# Out:
# /Users/zma/Documents/GitHub/isa_vehicle_detection/src

# %%
# !python app.py --video ../example_data/video/ISA\ Parking\ Placards.mp4 --output ./ISA_vehicle_output_video.mp4
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torch/hub.py:295: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/zma/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/zma/Library/Application Support/Ultralytics/settings.json'
# ...

# %%
# !python app.py --video ../example_data/video/ISA\ Parking\ Placards.mp4 --output ./original_output_video.mp4 --show-original
# Out:
# Using cache found in /Users/zma/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-10-6 Python-3.12.4 torch-2.4.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...
# Model loaded
# Detect and display
# /Users/zma/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/zma/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /Users/zma/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
